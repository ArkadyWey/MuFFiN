# %% [markdown]
# # 2 This is another title of a notebook

# %% [markdown]
# This is latex:
# $$x=2$$
# This is more latex:
# $$X=4$$
# The following will be some more code:

# %%
import muffin.parameters.parameters as parameters 

parameters = parameters.Parameters()
